# %%
import replicate
import os
os.environ["REPLICATE_API_TOKEN"] = "r8_7bVo5DjCM4MQBcsTer6tlaIiNDVqj084DrVjY"

# default_model = "replicate/vicuna-13b:6282abe6a492de4145d7bb601023762212f9ddbbe78278bd6771c8b3b2f2a13b"
default_model = "lucataco/vicuna-13b-v1.3:3166a8e442757658b9c23cec99d1553742e9ed2027ad7d2d99bcb4533260893e"

default_temperature = 0.8

# %%
prompt = f'Rephrase this sentence 5 times: "How are you feeling".'
output = replicate.run(default_model, input={"prompt": prompt})

# %%
print (output)

# %%
# %pip install openai

# %%
import openai

# OpenAI Key
os.environ["OPENAI_API_KEY"] = "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"
default_model = "gpt-4o-mini"
default_temperature = 0.8

# %%
open_prompt = 'Rephrase this sentence 5 times: "How are you feeling".'

response = openai.chat.completions.create(
    model=default_model,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": open_prompt},
    ],
    temperature=default_temperature,
)

print(response.choices[0].message.content)

# %%
import os
print(f"Token set: {bool(os.environ.get('REPLICATE_API_TOKEN'))}")
print(f"Token starts correctly: {os.environ.get('REPLICATE_API_TOKEN', '').startswith('r8_')}")

client = replicate.Client(api_token=os.environ["REPLICATE_API_TOKEN"])

# %%
import replicate
import os
os.environ["REPLICATE_API_TOKEN"] = "r8_7bVo5DjCM4MQBcsTer6tlaIiNDVqj084DrVjY"

default_model = "replicate/vicuna-13b:6282abe6a492de4145d7bb601023762212f9ddbbe78278bd6771c8b3b2f2a13b"
default_temperature = 0.8

# %%
prompt = f'Rephrase this sentence 5 times: "How are you feeling".'
# client = replicate.Client(api_token="r8_your_token_here")
output = client.run("replicate/vicuna-13b:6282abe6a492de4145d7bb601023762212f9ddbbe78278bd6771c8b3b2f2a13b", input={"prompt": prompt})


lucataco/vicuna-13b-v1.3:3166a8e442757658b9c23cec99d1553742e9ed2027ad7d2d99bcb4533260893e

# %%
prompt = f'Rephrase this sentence 5 times: "How are you feeling".'
output = replicate.run("replicate/vicuna-13b:6282abe6a492de4145d7bb601023762212f9ddbbe78278bd6771c8b3b2f2a13b", input={"prompt": prompt})
